# %%
import streamlit as st

st.set_page_config(page_title="คำนวนเงินเดือน", layout="centered")

st.title("คำนวณรายได้แยกรายการ")

rate = st.number_input("ค่าแรงต่อวัน", value=100.0)
hourly = rate / 8

def calculate_wage(shift_type, rate, hourly):
    """คำนวณค่าแรงตามประเภทกะ"""
    if shift_type in ['A', 'C']:
        return rate * 8
    elif shift_type in ['D', 'E']:
        return (rate * 8) + (rate * 1.5 * 2.5)
    elif shift_type in ['OTD', 'OTE']:
        return (rate * 2) + (hourly * 2.5 * 3)
    else:
        return 0

def calculate_meal(shift_type):
    """คำนวณค่าอาหารตามประเภทกะ"""
    if shift_type in ['A', 'C']:
        return 20
    elif shift_type in ['D', 'E']:
        return 35
    elif shift_type in ['OTD', 'OTE']:
        return 50
    else:
        return 0

def calculate_shift(shift_type):
    """คำนวณค่ากะตามประเภทกะ"""
    if shift_type in ['A', 'D', 'OTD']:
        return 10
    elif shift_type in ['C', 'E', 'OTE']:
        return 60
    else:
        return 0

# Input วันแต่ละกะ
st.subheader("จำนวนวันแต่ละกะ")
col1, col2, col3 = st.columns(3)

A = col1.number_input("A (เช้า)", 0, step=1, key='A_count')
D = col2.number_input("D (A+OT)", 0, step=1, key='D_count')
C = col3.number_input("C (ดึก)", 0, step=1, key='C_count')
E = col1.number_input("E (C+OT)", 0, step=1, key='E_count')
OTD = col2.number_input("OTD (วันหยุด)", 0, step=1, key='OTD_count')
OTE = col3.number_input("OTE (หยุด+ดึก)", 0, step=1, key='OTE_count')

# ข้อมูลแต่ละกะ
shifts = {
    'A': {'label': 'กะ A', 'count': A},
    'D': {'label': 'กะ D', 'count': D},
    'C': {'label': 'กะ C', 'count': C},
    'E': {'label': 'กะ E', 'count': E},
    'OTD': {'label': 'OTD', 'count': OTD},
    'OTE': {'label': 'OTE', 'count': OTE}
}

# คำนวณ
wage_total = meal_total = shift_total = total = 0

st.subheader("ผลลัพธ์")

for key, s in shifts.items():
    if s['count'] > 0:
        wage = calculate_wage(key, rate, hourly) * s['count']
        meal = calculate_meal(key) * s['count']
        shift = calculate_shift(key) * s['count']
        total_part = wage + meal + shift

        st.markdown(f"**{s['label']} × {s['count']} วัน**")
        st.markdown(f"- ค่าแรงรวม: {wage:,.2f} บาท")
        st.markdown(f"- ค่าข้าวรวม: {meal:,.2f} บาท")
        st.markdown(f"- ค่ากะรวม: {shift:,.2f} บาท")
        st.markdown(f"**ยอดรวม: {total_part:,.2f} บาท**")
        st.markdown("---")

        wage_total += wage
        meal_total += meal
        shift_total += shift
        total += total_part

# สรุปรวม
st.subheader("รวมทั้งหมด")
st.markdown(f"**ค่าแรงรวม:** {wage_total:,.2f} บาท")
st.markdown(f"**ค่าข้าวรวม:** {meal_total:,.2f} บาท")
st.markdown(f"**ค่ากะรวม:** {shift_total:,.2f} บาท")
st.markdown(f"**รวมสุทธิ:** {total:,.2f} บาท")
# Out:
# 2025-04-18 14:10:52.521 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:52.523 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.060
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\NB-01\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-04-18 14:10:53.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.064 Session state does not function when running a script without `streamlit run`
# 2025-04-18 14:10:53.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.071 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 14:10:53.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
